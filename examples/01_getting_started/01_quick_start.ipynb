# %% [markdown]
# # 最小構成で対戦を実行する
#
# 一番手軽な Player.battle_against() を使って勝敗を確認する。
#
# [▶ Google Colabで開く](https://colab.research.google.com/github/tmwork1/jpoke/blob/main/examples/01_basics/01_battle_against_intro.ipynb)

# %%
# %pip install -q jpoke
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from jpoke import Player, Battle

# %% [markdown]
# Player を用意する。

# %%
player1 = Player("Player 1")
player1.add_pokemon("ヒトカゲ", move_names=["ひっかく"])

player2 = Player("Player 2")
player2.add_pokemon("フシギダネ", move_names=["たいあたり"])

# %% [markdown]
# (方法1) Player.battle_against() を使う (poke-env 互換)

# %%
player1.battle_against(
    player2, seed=1, on_battle_end=lambda battle: battle.print_logs("all")
)
print(f"player1: 勝率{player1.win_rate:.0%}（{player1.n_finished_battles}戦）")
# Out:
# Turn 0 : Player 1 :  : バトル開始
# Turn 0 : Player 1 : ヒトカゲ : ヒトカゲ 入場
# Turn 0 : Player 2 : フシギダネ : フシギダネ 入場
# Turn 1 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 1 : Player 2 : フシギダネ : HP -19 (101/120)
# Turn 1 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 1 : Player 1 : ヒトカゲ : HP -19 (95/114)
# Turn 2 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 2 : Player 2 : フシギダネ : HP -17 (84/120)
# Turn 2 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 2 : Player 1 : ヒトカゲ : HP -19 (76/114)
# Turn 3 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 3 : Player 1 : ヒトカゲ : 急所に当たった！
# Turn 3 : Player 2 : フシギダネ : HP -27 (57/120)
# Turn 3 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 3 : Player 1 : ヒトカゲ : HP -21 (55/114)
# Turn 4 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 4 : Player 1 : ヒトカゲ : 急所に当たった！
# Turn 4 : Player 2 : フシギダネ : HP -25 (32/120)
# Turn 4 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 4 : Player 1 : ヒトカゲ : HP -19 (36/114)
# Turn 5 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 5 : Player 2 : フシギダネ : HP -17 (15/120)
# Turn 5 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 5 : Player 1 : ヒトカゲ : HP -19 (17/114)
# Turn 6 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 6 : Player 2 : フシギダネ : HP -15 (0/120)
# Turn 6 : Player 1 :  : 勝利
# Turn 6 : Player 2 :  : 敗北
# player1: 勝率100%（1戦）

# %% [markdown]
# (方法1) Battle を構築して play_out() を使う

# %%
battle = Battle(player1, player2, seed=1)
battle.play_out(max_turns=100)

battle.print_logs("all")
winner = battle.winner
print(f"勝者: {winner.username if winner else '引き分け'}")
# Out:
# Turn 0 : Player 1 :  : バトル開始
# Turn 0 : Player 1 : ヒトカゲ : ヒトカゲ 入場
# Turn 0 : Player 2 : フシギダネ : フシギダネ 入場
# Turn 1 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 1 : Player 2 : フシギダネ : HP -19 (101/120)
# Turn 1 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 1 : Player 1 : ヒトカゲ : HP -19 (95/114)
# Turn 2 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 2 : Player 2 : フシギダネ : HP -17 (84/120)
# Turn 2 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 2 : Player 1 : ヒトカゲ : HP -19 (76/114)
# Turn 3 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 3 : Player 1 : ヒトカゲ : 急所に当たった！
# Turn 3 : Player 2 : フシギダネ : HP -27 (57/120)
# Turn 3 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 3 : Player 1 : ヒトカゲ : HP -21 (55/114)
# Turn 4 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 4 : Player 1 : ヒトカゲ : 急所に当たった！
# Turn 4 : Player 2 : フシギダネ : HP -25 (32/120)
# Turn 4 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 4 : Player 1 : ヒトカゲ : HP -19 (36/114)
# Turn 5 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 5 : Player 2 : フシギダネ : HP -17 (15/120)
# Turn 5 : Player 2 : フシギダネ : たいあたり PP -1
# Turn 5 : Player 1 : ヒトカゲ : HP -19 (17/114)
# Turn 6 : Player 1 : ヒトカゲ : ひっかく PP -1
# Turn 6 : Player 2 : フシギダネ : HP -15 (0/120)
# Turn 6 : Player 1 :  : 勝利
# Turn 6 : Player 2 :  : 敗北
# 勝者: Player 1
