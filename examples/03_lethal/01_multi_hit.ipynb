# %% [markdown]
# # 連続技のダメージ計算

# %%
# %pip install -q jpoke
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from jpoke import Battle, Player

# %%
attack_player = Player("Attack Player")
attack_player.add_pokemon("ガブリアス")

defence_player = Player("Defence Player")
defence_player.add_pokemon("カイリュー", ability="マルチスケイル")

battle = Battle(attack_player, defence_player)
battle.start()

results = battle.calc_lethal(
    attacker=battle.get_active(attack_player),
    moves=[("スケイルショット", 5)] # (技, ヒット数) のように指定する
)

print(f"技: {results[0].move.name}")
for result in results:
    print("-"*50)
    print(f"攻撃回数: {result.attack_count}")
    print(f"ヒット回数: {result.hit_count}")
    print(f"ダメージ: {result.min_damage}~{result.max_damage}")
    print(f"HP分布: {result.hp_counter}")
    print(f"致死率: {result.lethal_probability:.2%}")
# Out:
# 技: スケイルショット
# --------------------------------------------------
# 攻撃回数: 1
# ヒット回数: 1
# ダメージ: 19~24
# HP分布: {142: 1, 144: 6, 145: 6, 147: 3}
# 致死率: 0.00%
# --------------------------------------------------
# 攻撃回数: 1
# ヒット回数: 2
# ダメージ: 38~48
# HP分布: {94: 1, 96: 6, 97: 6, 98: 6, 99: 3, 100: 42, 101: 36, 102: 36, 103: 54, 104: 3, 105: 18, 106: 18, 107: 18, 109: 9}
# 致死率: 0.00%
# --------------------------------------------------
# 攻撃回数: 1
# ヒット回数: 3
# ダメージ: 38~48
# HP分布: {46: 1, 48: 6, 49: 6, 50: 12, 51: 3, 52: 84, 53: 72, 54: 108, 55: 108, 56: 294, 57: 252, 58: 504, 59: 576, 60: 252, 61: 450, 62: 252, 63: 324, 64: 216, 65: 324, 66: 9, 67: 108, 68: 54, 69: 54, 71: 27}
# 致死率: 0.00%
# --------------------------------------------------
# 攻撃回数: 1
# ヒット回数: 4
# ダメージ: 38~48
# HP分布: {0: 7, 1: 6, 2: 18, 3: 3, 4: 126, 5: 108, 6: 216, 7: 162, 8: 873, 9: 702, 10: 1674, 11: 1674, 12: 2700, 13: 2619, 14: 5292, 15: 5508, 16: 5076, 17: 6804, 18: 3915, 19: 5508, 20: 4374, 21: 5670, 22: 2106, 23: 3969, 24: 1134, 25: 1944, 26: 972, 27: 1458, 28: 27, 29: 486, 30: 162, 31: 162, 33: 81}
# 致死率: 0.01%
